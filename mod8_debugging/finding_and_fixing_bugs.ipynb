# %% [markdown]
# # Debugging: Finding and Fixing Bugs

# %%
from TicTacToe import TicTacToe
game = TicTacToe()
# Out:
# Welcome to Tic Tac Toe!
# User input should be one of the moves below:
# top_left, top_center, top_right, middle_left, middle_center, middle_right, bottom_left, bottom_center, bottom_right

# %%
game.play_game()
# TicTacToe.__init__()
# TicTacToe.print_instructions()
# TicTacToe.__print_game_board()
# TicTacToe.__computer_take_turn()
# Out:
# Please enter a valid move.
#
#
# [[' ' ' ' ' ']
#  [' ' 'X' 'X']
#  [' ' ' ' ' ']]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 game.play_game()
#       2 # TicTacToe.__init__()
#       3 # TicTacToe.print_instructions()
#       4 # TicTacToe.__print_game_board()
#       5 # TicTacToe.__computer_take_turn()
#
# File ~/Documents/GitHub/bwsi-intro-python/mod8_debugging/TicTacToe.py:85, in TicTacToe.play_game(self)
#      81     print(message)
#      82     break
# ---> 85 self.__computer_take_turn()
#      86 end_game, message = self.__check_end_conditions("COMPUTER")
#      87 if end_game:
#
# TypeError: TicTacToe.__computer_take_turn() takes 0 positional arguments but 1 was given
