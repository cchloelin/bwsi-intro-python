# %% [markdown]
# # Debugging: Finding and Fixing Bugs

# %%
from TicTacToe import TicTacToe
game = TicTacToe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 2
#       1 from TicTacToe import TicTacToe
# ----> 2 game = TicTacToe()
#
# File ~/Documents/GitHub/bwsi-intro-python/mod8_debugging/TicTacToe.py:35, in TicTacToe.__init__(self)
#      33 self.board = np.zeros([3,3])
#      34 self.valid_moves = [move.value for move in MoveType]
# ---> 35 self.print_instrutions()
#
# AttributeError: 'TicTacToe' object has no attribute 'print_instrutions'

# %%
# game.play_game()
# TicTacToe.__init__()
# TicTacToe.print_instructions()
# TicTacToe.__print_game_board()
# TicTacToe.__computer_take_turn()
